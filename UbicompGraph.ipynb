# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from bokeh.plotting import figure, show

# %%
df = pd.read_csv('./GraphDataSet/ubicomp.csv',  index_col=None, header=None)
df.columns = ['True Label', 'Predicted Label', 'Accuracy']

# %%
df.head()
# Out:
#   True Label Predicted Label  Accuracy
# 0   Speaking        Speaking     64.85
# 1   Speaking          Eating     34.81
# 2   Speaking      Head_Shake      0.00
# 3   Speaking         Nodding      0.00
# 4   Speaking            Stay      0.00

# %%
matrix = [[64.85, 34.81, 0.00, 0.00, 0.00, 0.34], 
    [0.00, 56.42, 0.00, 0.41, 42.16, 1.02],
    [0.00, 1.20, 91.62, 1.27, 0.00, 5.84],
    [0.00, 0.50, 0.90, 98.10, 0.10, 0.40],
    [12.31, 13.06, 0.00, 0.00, 74.63, 0.00],
    [0.94, 10.68, 2.09, 2.62, 1.15, 82.51]]

LABELS = ['Speaking',
          'Eating',
          'Head_Shake',
          'Nodding',
         'Stay',
         'Walk']

plt.figure(figsize=(8, 6))
fmt = '.2f'
sns.heatmap(matrix,
            cmap='coolwarm',
            linecolor='white',
            linewidths=1,
            xticklabels=LABELS,
            yticklabels=LABELS,
            annot=True,
            fmt=fmt,vmin = 0, vmax = 100)
plt.title('Confusion Matrix')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.show()
